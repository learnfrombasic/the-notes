# %%
# !pip install -q -U 'tensorflow-text==2.8.*'
# !pip install -q tf-models-official==2.7.0
# !pip install tensorflow_addons
# !pip install -U --no-cache-di gdown --pre
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.0/498.0 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 KB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 44.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 46.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 29.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.4 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.8/dist-packages (0.19.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (23.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.3

# %%
from google.colab import drive

drive.mount("/content/drive")
# !cp '/content/drive/My Drive/Dataset/demake_up_data.zip' '/content'
# !unzip /content/demake_up_data.zip

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow.keras as keras

from tensorflow.keras import layers
from tensorflow.keras.models import Model
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# CONFIG PARAMETERS
BATCH_SIZE = 16
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNELS = 3
BUFFER_SIZE = BATCH_SIZE * 10
IMG_PATH = "/content/demake_up_data"
EPOCHS = 20

np.random.seed(69)

# %% [markdown]
# # Data processing

# %%
def load(img_file):
    makeup_img_file, non_img_file = tf.split(img_file, 2)

    makeup_img = tf.io.read_file(makeup_img_file[0])
    makeup_img = tf.image.decode_jpeg(makeup_img, channels=IMG_CHANNELS)

    non_img = tf.io.read_file(non_img_file[0])
    non_img = tf.image.decode_jpeg(non_img, channels=IMG_CHANNELS)

    makeup_img = tf.cast(makeup_img, tf.float32)
    non_img = tf.cast(non_img, tf.float32)

    return makeup_img, non_img

# %%
makeup_img, non_img = load(
    [str(IMG_PATH + "/train/makeup/0.png"), str(IMG_PATH + "/train/non-makeup/0.png")]
)
print(makeup_img.shape)
print(non_img.shape)

plt.figure(figsize=(10, 8))
plt.imshow(makeup_img / 255.0)

plt.figure(figsize=(10, 8))
plt.imshow(non_img / 255.0)

# %%
@tf.function
def random_flip(makeup_img, non_img):
    if tf.random.uniform(()) > 0.5:
        # Random_mirroring
        makeup_img = tf.image.flip_left_right(makeup_img)
        non_img = tf.image.flip_left_right(non_img)
    return makeup_img, non_img


def processing_image(makeup_img, non_img):
    makeup_img = makeup_img / 255.0
    non_img = non_img / 255.0
    return makeup_img, non_img


def load_image_train(image_file):
    makeup_img, non_img = load(image_file)
    makeup_img, non_img = random_flip(makeup_img, non_img)
    makeup_img, non_img = processing_image(makeup_img, non_img)
    return makeup_img, non_img


def load_image_val(image_file):
    makeup_img, non_img = load(image_file)
    makeup_img, non_img = processing_image(makeup_img, non_img)
    return makeup_img, non_img

# %%
def prepare_data(path):
    makeup_img_list = [os.path.join(path, f) for f in os.listdir(path)]
    data_list = [[i, i.replace("makeup", "non-makeup")] for i in makeup_img_list]
    return data_list


train_data_list = prepare_data(str(IMG_PATH + "/train/makeup/"))
val_data_list = prepare_data(str(IMG_PATH + "/val/makeup/"))
test_data_list = prepare_data(str(IMG_PATH + "/test/makeup"))

np.random.shuffle(train_data_list)
np.random.shuffle(val_data_list)
np.random.shuffle(test_data_list)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(train_data_list)
train_dataset = train_dataset.map(load_image_train, num_parallel_calls=tf.data.AUTOTUNE)
train_datatset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE)


val_dataset = tf.data.Dataset.from_tensor_slices(val_data_list)
val_dataset = val_dataset.map(load_image_val)
val_dataset = val_dataset.batch(BATCH_SIZE)


test_dataset = tf.data.Dataset.from_tensor_slices(test_data_list)
test_dataset = test_dataset.map(load_image_val)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Model Implementation

# %%
class ResNetBlock:
    def __init__(self):
        pass

    def init_block(self, inputs):
        x = keras.layers.ZeroPadding2D(padding=3)(inputs)
        x = keras.layers.Conv2D(64, kernel_size=(7, 7), strides=2)(x)
        x = tfa.layers.InstanceNormalization()(x)
        x = keras.layers.Activation("gelu")(x)
        return x

    def identity_block(self, inputs, n_filters):
        x = keras.layers.Conv2D(
            n_filters, kernel_size=(3, 3), padding="same", use_bias=False
        )(inputs)
        x = tfa.layers.InstanceNormalization()(x)
        x = keras.layers.Activation("gelu")(x)
        x = keras.layers.Conv2D(
            n_filters, kernel_size=(3, 3), padding="same", use_bias=False
        )(x)
        x = tfa.layers.InstanceNormalization()(x)
        skip_connection = keras.layers.Add()([inputs, x])
        x = keras.layers.Activation("relu")(skip_connection)
        return x

    def projection_block(self, inputs, filters, strides=2):
        x = keras.layers.Conv2D(
            filters=filters,
            kernel_size=(3, 3),
            padding="same",
            strides=strides,
            use_bias=False,
        )(inputs)
        x = tfa.layers.InstanceNormalization()(x)
        x = keras.layers.Activation("gelu")(x)
        x = keras.layers.Conv2D(
            filters=filters, kernel_size=(3, 3), padding="same", use_bias=False
        )(x)
        x = tfa.layers.InstanceNormalization()(x)
        shortcut = keras.layers.Conv2D(
            filters=filters,
            kernel_size=(1, 1),
            padding="same",
            strides=strides,
            use_bias=False,
        )(inputs)
        shortcut = tfa.layers.InstanceNormalization()(shortcut)
        skip_connection = keras.layers.Add()([shortcut, x])
        x = keras.layers.Activation("gelu")(skip_connection)
        return x

    def build_block(self, inputs, filters, n_iter, projection_block=False):
        layer = inputs
        if projection_block == True:
            layer = self.projection_block(layer, filters, strides=2)
        for iter in range(n_iter):
            layer = self.identity_block(layer, filters)
        return layer

# %%
class MultiTasking:
    def __init__(self):
        pass

    def task(self):
        pass

    def conv_block(self, inputs, num_filters):
        x = layers.Conv2D(filters=num_filters, kernel_size=(3, 3), padding="same")(
            inputs
        )
        x = tfa.layers.InstanceNormalization()(x)
        x = layers.Activation("gelu")(x)
        return x


class Task1(MultiTasking):
    def __init__(self):
        pass

    def task(self, input_feature):
        non_feature = self.conv_block(input_feature, 32)
        non_feature = self.conv_block(non_feature, 16)
        output = layers.Conv2D(3, kernel_size=(1, 1), activation="sigmoid")(non_feature)
        return output


class Task2(MultiTasking):
    def __init__(self):
        pass

    def task(self, input_feature):
        sr_feature = layers.Conv2DTranspose(
            32, kernel_size=(2, 2), strides=2, padding="same"
        )(input_feature)
        sr_feature = layers.Conv2DTranspose(
            16, kernel_size=(2, 2), strides=2, padding="same"
        )(sr_feature)
        output = layers.Conv2D(3, kernel_size=(1, 1), activation="sigmoid")(sr_feature)
        return output

# %%
class Res34UNetMultiTask:
    def __init__(self):
        self.res34 = ResNetBlock()
        self.task1 = Task1()
        self.task2 = Task2()

    def conv_block(self, inputs, num_filters):
        x = layers.Conv2D(filters=num_filters, kernel_size=(3, 3), padding="same")(
            inputs
        )
        x = tfa.layers.InstanceNormalization()(x)
        x = layers.Activation("gelu")(x)
        return x

    def downsampling(self, inputs, n_filters, n_iter, projection_block=False):
        down = self.res34.build_block(inputs, n_filters, n_iter, projection_block)
        branch = keras.layers.Dropout(0.3)(down)
        return down, branch

    def upsampling(self, up_inputs, branch_inputs, n_filters):
        x_up = keras.layers.Conv2DTranspose(
            n_filters, kernel_size=(2, 2), padding="same", strides=2
        )(up_inputs)
        x = keras.layers.concatenate([x_up, branch_inputs])
        x = self.conv_block(x, n_filters)
        return x

    def build_model(self, input_shape=(IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS)):
        # Inputs
        inputs = keras.layers.Input(shape=input_shape)

        # Encoder: ResNet3
        init_block = self.res34.init_block(inputs)
        pre_second_block = keras.layers.ZeroPadding2D(padding=1)(init_block)
        pre_second_block = keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2)(
            pre_second_block
        )
        down2, branch2 = self.downsampling(pre_second_block, 64, 3, False)
        down3, branch3 = self.downsampling(down2, 128, 4, True)
        down4, branch4 = self.downsampling(down3, 256, 6, True)

        # Bridge
        down5, branch5 = self.downsampling(down4, 512, 3, True)
        bridge = down5

        # Decoder
        up4 = self.upsampling(bridge, down4, 512)
        up3 = self.upsampling(up4, branch3, 256)
        up2 = self.upsampling(up3, branch2, 128)
        up1 = self.upsampling(up2, init_block, 64)
        init_branch = keras.layers.Conv2D(
            64, kernel_size=(1, 1), padding="same", strides=1
        )(inputs)
        up0 = self.upsampling(up1, init_branch, 64)

        # Output
        first_feature = layers.Conv2D(64, kernel_size=(3, 3), padding="same")(inputs)
        first_feature = layers.Conv2DTranspose(
            64, kernel_size=(2, 2), padding="same", strides=2
        )(first_feature)
        final_feature = self.upsampling(up0, first_feature, 64)
        outputs1 = self.task1.task(final_feature)
        outputs2 = self.task2.task(final_feature)
        model = Model(inputs=inputs, outputs=[outputs1, outputs2])
        return model

# %%
model = Res34UNetMultiTask()
res34unet = model.build_model(input_shape=(IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
res34unet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_44 (ZeroPadding  (None, 230, 230, 3)  0          ['input_23[0][0]']
#  2D)
#
#  conv2d_1088 (Conv2D)           (None, 112, 112, 64  9472        ['zero_padding2d_44[0][0]']
#                                 )
#
#  instance_normalization_1048 (I  (None, 112, 112, 64  128        ['conv2d_1088[0][0]']
#  nstanceNormalization)          )
#
#  activation_982 (Activation)    (None, 112, 112, 64  0           ['instance_normalization_1048[0][
#                                 )                                0]']
#
#  zero_padding2d_45 (ZeroPadding  (None, 114, 114, 64  0          ['activation_982[0][0]']
#  2D)                            )
#
#  max_pooling2d_22 (MaxPooling2D  (None, 56, 56, 64)  0           ['zero_padding2d_45[0][0]']
#  )
#
#  conv2d_1089 (Conv2D)           (None, 56, 56, 64)   36864       ['max_pooling2d_22[0][0]']
#
#  instance_normalization_1049 (I  (None, 56, 56, 64)  128         ['conv2d_1089[0][0]']
#  nstanceNormalization)
#
#  activation_983 (Activation)    (None, 56, 56, 64)   0           ['instance_normalization_1049[0][
#                                                                  0]']
#
#  conv2d_1090 (Conv2D)           (None, 56, 56, 64)   36864       ['activation_983[0][0]']
#
#  instance_normalization_1050 (I  (None, 56, 56, 64)  128         ['conv2d_1090[0][0]']
#  nstanceNormalization)
#
#  add_418 (Add)                  (None, 56, 56, 64)   0           ['max_pooling2d_22[0][0]',
#                                                                   'instance_normalization_1050[0][
#                                                                  0]']
#
#  activation_984 (Activation)    (None, 56, 56, 64)   0           ['add_418[0][0]']
#
#  conv2d_1091 (Conv2D)           (None, 56, 56, 64)   36864       ['activation_984[0][0]']
#
#  instance_normalization_1051 (I  (None, 56, 56, 64)  128         ['conv2d_1091[0][0]']
#  nstanceNormalization)
#
#  activation_985 (Activation)    (None, 56, 56, 64)   0           ['instance_normalization_1051[0][
#                                                                  0]']
#
#  conv2d_1092 (Conv2D)           (None, 56, 56, 64)   36864       ['activation_985[0][0]']
#
#  instance_normalization_1052 (I  (None, 56, 56, 64)  128         ['conv2d_1092[0][0]']
#  nstanceNormalization)
#
#  add_419 (Add)                  (None, 56, 56, 64)   0           ['activation_984[0][0]',
#                                                                   'instance_normalization_1052[0][
#                                                                  0]']
#
#  activation_986 (Activation)    (None, 56, 56, 64)   0           ['add_419[0][0]']
#
#  conv2d_1093 (Conv2D)           (None, 56, 56, 64)   36864       ['activation_986[0][0]']
#
#  instance_normalization_1053 (I  (None, 56, 56, 64)  128         ['conv2d_1093[0][0]']
#  nstanceNormalization)
#
#  activation_987 (Activation)    (None, 56, 56, 64)   0           ['instance_normalization_1053[0][
#                                                                  0]']
#
#  conv2d_1094 (Conv2D)           (None, 56, 56, 64)   36864       ['activation_987[0][0]']
#
#  instance_normalization_1054 (I  (None, 56, 56, 64)  128         ['conv2d_1094[0][0]']
#  nstanceNormalization)
#
#  add_420 (Add)                  (None, 56, 56, 64)   0           ['activation_986[0][0]',
#                                                                   'instance_normalization_1054[0][
#                                                                  0]']
#
#  activation_988 (Activation)    (None, 56, 56, 64)   0           ['add_420[0][0]']
#
#  conv2d_1095 (Conv2D)           (None, 28, 28, 128)  73728       ['activation_988[0][0]']
#
#  instance_normalization_1055 (I  (None, 28, 28, 128)  256        ['conv2d_1095[0][0]']
#  nstanceNormalization)
#
#  activation_989 (Activation)    (None, 28, 28, 128)  0           ['instance_normalization_1055[0][
#                                                                  0]']
#
#  conv2d_1097 (Conv2D)           (None, 28, 28, 128)  8192        ['activation_988[0][0]']
#
#  conv2d_1096 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_989[0][0]']
#
#  instance_normalization_1057 (I  (None, 28, 28, 128)  256        ['conv2d_1097[0][0]']
#  nstanceNormalization)
#
#  instance_normalization_1056 (I  (None, 28, 28, 128)  256        ['conv2d_1096[0][0]']
#  nstanceNormalization)
#
#  add_421 (Add)                  (None, 28, 28, 128)  0           ['instance_normalization_1057[0][
#                                                                  0]',
#                                                                   'instance_normalization_1056[0][
#                                                                  0]']
#
#  activation_990 (Activation)    (None, 28, 28, 128)  0           ['add_421[0][0]']
#
#  conv2d_1098 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_990[0][0]']
#
#  instance_normalization_1058 (I  (None, 28, 28, 128)  256        ['conv2d_1098[0][0]']
#  nstanceNormalization)
#
#  activation_991 (Activation)    (None, 28, 28, 128)  0           ['instance_normalization_1058[0][
#                                                                  0]']
#
#  conv2d_1099 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_991[0][0]']
#
#  instance_normalization_1059 (I  (None, 28, 28, 128)  256        ['conv2d_1099[0][0]']
#  nstanceNormalization)
#
#  add_422 (Add)                  (None, 28, 28, 128)  0           ['activation_990[0][0]',
#                                                                   'instance_normalization_1059[0][
#                                                                  0]']
#
#  activation_992 (Activation)    (None, 28, 28, 128)  0           ['add_422[0][0]']
#
#  conv2d_1100 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_992[0][0]']
#
#  instance_normalization_1060 (I  (None, 28, 28, 128)  256        ['conv2d_1100[0][0]']
#  nstanceNormalization)
#
#  activation_993 (Activation)    (None, 28, 28, 128)  0           ['instance_normalization_1060[0][
#                                                                  0]']
#
#  conv2d_1101 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_993[0][0]']
#
#  instance_normalization_1061 (I  (None, 28, 28, 128)  256        ['conv2d_1101[0][0]']
#  nstanceNormalization)
#
#  add_423 (Add)                  (None, 28, 28, 128)  0           ['activation_992[0][0]',
#                                                                   'instance_normalization_1061[0][
#                                                                  0]']
#
#  activation_994 (Activation)    (None, 28, 28, 128)  0           ['add_423[0][0]']
#
#  conv2d_1102 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_994[0][0]']
#
#  instance_normalization_1062 (I  (None, 28, 28, 128)  256        ['conv2d_1102[0][0]']
#  nstanceNormalization)
#
#  activation_995 (Activation)    (None, 28, 28, 128)  0           ['instance_normalization_1062[0][
#                                                                  0]']
#
#  conv2d_1103 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_995[0][0]']
#
#  instance_normalization_1063 (I  (None, 28, 28, 128)  256        ['conv2d_1103[0][0]']
#  nstanceNormalization)
#
#  add_424 (Add)                  (None, 28, 28, 128)  0           ['activation_994[0][0]',
#                                                                   'instance_normalization_1063[0][
#                                                                  0]']
#
#  activation_996 (Activation)    (None, 28, 28, 128)  0           ['add_424[0][0]']
#
#  conv2d_1104 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_996[0][0]']
#
#  instance_normalization_1064 (I  (None, 28, 28, 128)  256        ['conv2d_1104[0][0]']
#  nstanceNormalization)
#
#  activation_997 (Activation)    (None, 28, 28, 128)  0           ['instance_normalization_1064[0][
#                                                                  0]']
#
#  conv2d_1105 (Conv2D)           (None, 28, 28, 128)  147456      ['activation_997[0][0]']
#
#  instance_normalization_1065 (I  (None, 28, 28, 128)  256        ['conv2d_1105[0][0]']
#  nstanceNormalization)
#
#  add_425 (Add)                  (None, 28, 28, 128)  0           ['activation_996[0][0]',
#                                                                   'instance_normalization_1065[0][
#                                                                  0]']
#
#  activation_998 (Activation)    (None, 28, 28, 128)  0           ['add_425[0][0]']
#
#  conv2d_1106 (Conv2D)           (None, 14, 14, 256)  294912      ['activation_998[0][0]']
#
#  instance_normalization_1066 (I  (None, 14, 14, 256)  512        ['conv2d_1106[0][0]']
#  nstanceNormalization)
#
#  activation_999 (Activation)    (None, 14, 14, 256)  0           ['instance_normalization_1066[0][
#                                                                  0]']
#
#  conv2d_1108 (Conv2D)           (None, 14, 14, 256)  32768       ['activation_998[0][0]']
#
#  conv2d_1107 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_999[0][0]']
#
#  instance_normalization_1068 (I  (None, 14, 14, 256)  512        ['conv2d_1108[0][0]']
#  nstanceNormalization)
#
#  instance_normalization_1067 (I  (None, 14, 14, 256)  512        ['conv2d_1107[0][0]']
#  nstanceNormalization)
#
#  add_426 (Add)                  (None, 14, 14, 256)  0           ['instance_normalization_1068[0][
#                                                                  0]',
#                                                                   'instance_normalization_1067[0][
#                                                                  0]']
#
#  activation_1000 (Activation)   (None, 14, 14, 256)  0           ['add_426[0][0]']
#
#  conv2d_1109 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1000[0][0]']
#
#  instance_normalization_1069 (I  (None, 14, 14, 256)  512        ['conv2d_1109[0][0]']
#  nstanceNormalization)
#
#  activation_1001 (Activation)   (None, 14, 14, 256)  0           ['instance_normalization_1069[0][
#                                                                  0]']
#
#  conv2d_1110 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1001[0][0]']
#
#  instance_normalization_1070 (I  (None, 14, 14, 256)  512        ['conv2d_1110[0][0]']
#  nstanceNormalization)
#
#  add_427 (Add)                  (None, 14, 14, 256)  0           ['activation_1000[0][0]',
#                                                                   'instance_normalization_1070[0][
#                                                                  0]']
#
#  activation_1002 (Activation)   (None, 14, 14, 256)  0           ['add_427[0][0]']
#
#  conv2d_1111 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1002[0][0]']
#
#  instance_normalization_1071 (I  (None, 14, 14, 256)  512        ['conv2d_1111[0][0]']
#  nstanceNormalization)
#
#  activation_1003 (Activation)   (None, 14, 14, 256)  0           ['instance_normalization_1071[0][
#                                                                  0]']
#
#  conv2d_1112 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1003[0][0]']
#
#  instance_normalization_1072 (I  (None, 14, 14, 256)  512        ['conv2d_1112[0][0]']
#  nstanceNormalization)
#
#  add_428 (Add)                  (None, 14, 14, 256)  0           ['activation_1002[0][0]',
#                                                                   'instance_normalization_1072[0][
#                                                                  0]']
#
#  activation_1004 (Activation)   (None, 14, 14, 256)  0           ['add_428[0][0]']
#
#  conv2d_1113 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1004[0][0]']
#
#  instance_normalization_1073 (I  (None, 14, 14, 256)  512        ['conv2d_1113[0][0]']
#  nstanceNormalization)
#
#  activation_1005 (Activation)   (None, 14, 14, 256)  0           ['instance_normalization_1073[0][
#                                                                  0]']
#
#  conv2d_1114 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1005[0][0]']
#
#  instance_normalization_1074 (I  (None, 14, 14, 256)  512        ['conv2d_1114[0][0]']
#  nstanceNormalization)
#
#  add_429 (Add)                  (None, 14, 14, 256)  0           ['activation_1004[0][0]',
#                                                                   'instance_normalization_1074[0][
#                                                                  0]']
#
#  activation_1006 (Activation)   (None, 14, 14, 256)  0           ['add_429[0][0]']
#
#  conv2d_1115 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1006[0][0]']
#
#  instance_normalization_1075 (I  (None, 14, 14, 256)  512        ['conv2d_1115[0][0]']
#  nstanceNormalization)
#
#  activation_1007 (Activation)   (None, 14, 14, 256)  0           ['instance_normalization_1075[0][
#                                                                  0]']
#
#  conv2d_1116 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1007[0][0]']
#
#  instance_normalization_1076 (I  (None, 14, 14, 256)  512        ['conv2d_1116[0][0]']
#  nstanceNormalization)
#
#  add_430 (Add)                  (None, 14, 14, 256)  0           ['activation_1006[0][0]',
#                                                                   'instance_normalization_1076[0][
#                                                                  0]']
#
#  activation_1008 (Activation)   (None, 14, 14, 256)  0           ['add_430[0][0]']
#
#  conv2d_1117 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1008[0][0]']
#
#  instance_normalization_1077 (I  (None, 14, 14, 256)  512        ['conv2d_1117[0][0]']
#  nstanceNormalization)
#
#  activation_1009 (Activation)   (None, 14, 14, 256)  0           ['instance_normalization_1077[0][
#                                                                  0]']
#
#  conv2d_1118 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1009[0][0]']
#
#  instance_normalization_1078 (I  (None, 14, 14, 256)  512        ['conv2d_1118[0][0]']
#  nstanceNormalization)
#
#  add_431 (Add)                  (None, 14, 14, 256)  0           ['activation_1008[0][0]',
#                                                                   'instance_normalization_1078[0][
#                                                                  0]']
#
#  activation_1010 (Activation)   (None, 14, 14, 256)  0           ['add_431[0][0]']
#
#  conv2d_1119 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1010[0][0]']
#
#  instance_normalization_1079 (I  (None, 14, 14, 256)  512        ['conv2d_1119[0][0]']
#  nstanceNormalization)
#
#  activation_1011 (Activation)   (None, 14, 14, 256)  0           ['instance_normalization_1079[0][
#                                                                  0]']
#
#  conv2d_1120 (Conv2D)           (None, 14, 14, 256)  589824      ['activation_1011[0][0]']
#
#  instance_normalization_1080 (I  (None, 14, 14, 256)  512        ['conv2d_1120[0][0]']
#  nstanceNormalization)
#
#  add_432 (Add)                  (None, 14, 14, 256)  0           ['activation_1010[0][0]',
#                                                                   'instance_normalization_1080[0][
#                                                                  0]']
#
#  activation_1012 (Activation)   (None, 14, 14, 256)  0           ['add_432[0][0]']
#
#  conv2d_1121 (Conv2D)           (None, 7, 7, 512)    1179648     ['activation_1012[0][0]']
#
#  instance_normalization_1081 (I  (None, 7, 7, 512)   1024        ['conv2d_1121[0][0]']
#  nstanceNormalization)
#
#  activation_1013 (Activation)   (None, 7, 7, 512)    0           ['instance_normalization_1081[0][
#                                                                  0]']
#
#  conv2d_1123 (Conv2D)           (None, 7, 7, 512)    131072      ['activation_1012[0][0]']
#
#  conv2d_1122 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1013[0][0]']
#
#  instance_normalization_1083 (I  (None, 7, 7, 512)   1024        ['conv2d_1123[0][0]']
#  nstanceNormalization)
#
#  instance_normalization_1082 (I  (None, 7, 7, 512)   1024        ['conv2d_1122[0][0]']
#  nstanceNormalization)
#
#  add_433 (Add)                  (None, 7, 7, 512)    0           ['instance_normalization_1083[0][
#                                                                  0]',
#                                                                   'instance_normalization_1082[0][
#                                                                  0]']
#
#  activation_1014 (Activation)   (None, 7, 7, 512)    0           ['add_433[0][0]']
#
#  conv2d_1124 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1014[0][0]']
#
#  instance_normalization_1084 (I  (None, 7, 7, 512)   1024        ['conv2d_1124[0][0]']
#  nstanceNormalization)
#
#  activation_1015 (Activation)   (None, 7, 7, 512)    0           ['instance_normalization_1084[0][
#                                                                  0]']
#
#  conv2d_1125 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1015[0][0]']
#
#  instance_normalization_1085 (I  (None, 7, 7, 512)   1024        ['conv2d_1125[0][0]']
#  nstanceNormalization)
#
#  add_434 (Add)                  (None, 7, 7, 512)    0           ['activation_1014[0][0]',
#                                                                   'instance_normalization_1085[0][
#                                                                  0]']
#
#  activation_1016 (Activation)   (None, 7, 7, 512)    0           ['add_434[0][0]']
#
#  conv2d_1126 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1016[0][0]']
#
#  instance_normalization_1086 (I  (None, 7, 7, 512)   1024        ['conv2d_1126[0][0]']
#  nstanceNormalization)
#
#  activation_1017 (Activation)   (None, 7, 7, 512)    0           ['instance_normalization_1086[0][
#                                                                  0]']
#
#  conv2d_1127 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1017[0][0]']
#
#  instance_normalization_1087 (I  (None, 7, 7, 512)   1024        ['conv2d_1127[0][0]']
#  nstanceNormalization)
#
#  add_435 (Add)                  (None, 7, 7, 512)    0           ['activation_1016[0][0]',
#                                                                   'instance_normalization_1087[0][
#                                                                  0]']
#
#  activation_1018 (Activation)   (None, 7, 7, 512)    0           ['add_435[0][0]']
#
#  conv2d_1128 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1018[0][0]']
#
#  instance_normalization_1088 (I  (None, 7, 7, 512)   1024        ['conv2d_1128[0][0]']
#  nstanceNormalization)
#
#  activation_1019 (Activation)   (None, 7, 7, 512)    0           ['instance_normalization_1088[0][
#                                                                  0]']
#
#  conv2d_1129 (Conv2D)           (None, 7, 7, 512)    2359296     ['activation_1019[0][0]']
#
#  instance_normalization_1089 (I  (None, 7, 7, 512)   1024        ['conv2d_1129[0][0]']
#  nstanceNormalization)
#
#  add_436 (Add)                  (None, 7, 7, 512)    0           ['activation_1018[0][0]',
#                                                                   'instance_normalization_1089[0][
#                                                                  0]']
#
#  activation_1020 (Activation)   (None, 7, 7, 512)    0           ['add_436[0][0]']
#
#  conv2d_transpose_145 (Conv2DTr  (None, 14, 14, 512)  1049088    ['activation_1020[0][0]']
#  anspose)
#
#  concatenate_132 (Concatenate)  (None, 14, 14, 768)  0           ['conv2d_transpose_145[0][0]',
#                                                                   'activation_1012[0][0]']
#
#  conv2d_1130 (Conv2D)           (None, 14, 14, 512)  3539456     ['concatenate_132[0][0]']
#
#  instance_normalization_1090 (I  (None, 14, 14, 512)  1024       ['conv2d_1130[0][0]']
#  nstanceNormalization)
#
#  activation_1021 (Activation)   (None, 14, 14, 512)  0           ['instance_normalization_1090[0][
#                                                                  0]']
#
#  conv2d_transpose_146 (Conv2DTr  (None, 28, 28, 256)  524544     ['activation_1021[0][0]']
#  anspose)
#
#  dropout_89 (Dropout)           (None, 28, 28, 128)  0           ['activation_998[0][0]']
#
#  concatenate_133 (Concatenate)  (None, 28, 28, 384)  0           ['conv2d_transpose_146[0][0]',
#                                                                   'dropout_89[0][0]']
#
#  conv2d_1131 (Conv2D)           (None, 28, 28, 256)  884992      ['concatenate_133[0][0]']
#
#  instance_normalization_1091 (I  (None, 28, 28, 256)  512        ['conv2d_1131[0][0]']
#  nstanceNormalization)
#
#  activation_1022 (Activation)   (None, 28, 28, 256)  0           ['instance_normalization_1091[0][
#                                                                  0]']
#
#  conv2d_transpose_147 (Conv2DTr  (None, 56, 56, 128)  131200     ['activation_1022[0][0]']
#  anspose)
#
#  dropout_88 (Dropout)           (None, 56, 56, 64)   0           ['activation_988[0][0]']
#
#  concatenate_134 (Concatenate)  (None, 56, 56, 192)  0           ['conv2d_transpose_147[0][0]',
#                                                                   'dropout_88[0][0]']
#
#  conv2d_1132 (Conv2D)           (None, 56, 56, 128)  221312      ['concatenate_134[0][0]']
#
#  instance_normalization_1092 (I  (None, 56, 56, 128)  256        ['conv2d_1132[0][0]']
#  nstanceNormalization)
#
#  activation_1023 (Activation)   (None, 56, 56, 128)  0           ['instance_normalization_1092[0][
#                                                                  0]']
#
#  conv2d_transpose_148 (Conv2DTr  (None, 112, 112, 64  32832      ['activation_1023[0][0]']
#  anspose)                       )
#
#  concatenate_135 (Concatenate)  (None, 112, 112, 12  0           ['conv2d_transpose_148[0][0]',
#                                 8)                                'activation_982[0][0]']
#
#  conv2d_1133 (Conv2D)           (None, 112, 112, 64  73792       ['concatenate_135[0][0]']
#                                 )
#
#  instance_normalization_1093 (I  (None, 112, 112, 64  128        ['conv2d_1133[0][0]']
#  nstanceNormalization)          )
#
#  activation_1024 (Activation)   (None, 112, 112, 64  0           ['instance_normalization_1093[0][
#                                 )                                0]']
#
#  conv2d_transpose_149 (Conv2DTr  (None, 224, 224, 64  16448      ['activation_1024[0][0]']
#  anspose)                       )
#
#  conv2d_1134 (Conv2D)           (None, 224, 224, 64  256         ['input_23[0][0]']
#                                 )
#
#  concatenate_136 (Concatenate)  (None, 224, 224, 12  0           ['conv2d_transpose_149[0][0]',
#                                 8)                                'conv2d_1134[0][0]']
#
#  conv2d_1135 (Conv2D)           (None, 224, 224, 64  73792       ['concatenate_136[0][0]']
#                                 )
#
#  instance_normalization_1094 (I  (None, 224, 224, 64  128        ['conv2d_1135[0][0]']
#  nstanceNormalization)          )
#
#  activation_1025 (Activation)   (None, 224, 224, 64  0           ['instance_normalization_1094[0][
#                                 )                                0]']
#
#  conv2d_1136 (Conv2D)           (None, 224, 224, 64  1792        ['input_23[0][0]']
#                                 )
#
#  conv2d_transpose_151 (Conv2DTr  (None, 448, 448, 64  16448      ['activation_1025[0][0]']
#  anspose)                       )
#
#  conv2d_transpose_150 (Conv2DTr  (None, 448, 448, 64  16448      ['conv2d_1136[0][0]']
#  anspose)                       )
#
#  concatenate_137 (Concatenate)  (None, 448, 448, 12  0           ['conv2d_transpose_151[0][0]',
#                                 8)                                'conv2d_transpose_150[0][0]']
#
#  conv2d_1137 (Conv2D)           (None, 448, 448, 64  73792       ['concatenate_137[0][0]']
#                                 )
#
#  instance_normalization_1095 (I  (None, 448, 448, 64  128        ['conv2d_1137[0][0]']
#  nstanceNormalization)          )
#
#  activation_1026 (Activation)   (None, 448, 448, 64  0           ['instance_normalization_1095[0][
#                                 )                                0]']
#
#  conv2d_1138 (Conv2D)           (None, 448, 448, 32  18464       ['activation_1026[0][0]']
#                                 )
#
#  instance_normalization_1096 (I  (None, 448, 448, 32  64         ['conv2d_1138[0][0]']
#  nstanceNormalization)          )
#
#  activation_1027 (Activation)   (None, 448, 448, 32  0           ['instance_normalization_1096[0][
#                                 )                                0]']
#
#  conv2d_1139 (Conv2D)           (None, 448, 448, 16  4624        ['activation_1027[0][0]']
#                                 )
#
#  instance_normalization_1097 (I  (None, 448, 448, 16  32         ['conv2d_1139[0][0]']
#  nstanceNormalization)          )
#
#  conv2d_transpose_152 (Conv2DTr  (None, 896, 896, 32  8224       ['activation_1026[0][0]']
#  anspose)                       )
#
#  activation_1028 (Activation)   (None, 448, 448, 16  0           ['instance_normalization_1097[0][
#                                 )                                0]']
#
#  conv2d_transpose_153 (Conv2DTr  (None, 1792, 1792,   2064       ['conv2d_transpose_152[0][0]']
#  anspose)                       16)
#
#  conv2d_1140 (Conv2D)           (None, 448, 448, 3)  51          ['activation_1028[0][0]']
#
#  conv2d_1141 (Conv2D)           (None, 1792, 1792,   51          ['conv2d_transpose_153[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 34,173,414
# Trainable params: 34,173,414
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
def evaluate(model, epoch, dataset):
    psnr_non_mean = 0.0
    psnr_sr_mean = 0.0
    count = 0
    for makeup_img, non_img, hr_img in dataset:
        pred_non, pred_sr = model([makeup_img], training=False)

        psnr_non = tf.image.psnr(pred_non, non_img, max_val=1.0)
        psnr_sr = tf.image.psnr(pred_sr, hr_img, max_val=1.0)

        __psnr_non_mean = tf.math.reduce_mean(psnr_non)
        __psnr_sr_mean = tf.math.reduce_mean(psnr_sr)
        # psnr_mean = psnr_mean_l

        psnr_non_mean += __psnr_non_mean
        psnr_sr_mean += __psnr_sr_mean
        count = count + 1

    psnr_non_mean = psnr_non_mean / count
    psnr_sr_mean = psnr_sr_mean / count
    print(
        "-------- psnr_non: ",
        psnr_non_mean.numpy(),
        "psnr_sr: ",
        psnr_sr_mean.numpy(),
        "   ----- epoch: ",
        epoch,
        "  count: ",
        count,
    )

    return psnr_non_mean, psnr_sr_mean


def generate_images(model, makeup_img, non_img, hr_img):
    pred_non, pred_sr = model([makeup_img], training=False)
    plt.figure(figsize=(15, 20))

    display_list = [makeup_img[0], non_img[0], pred_non[0]]

    title = ["Input", "Non-makeup", "Predicted"]

    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.title(title[i])
        plt.imshow(display_list[i])
        plt.axis("off")
    plt.show()

    display_list2 = [hr_img[0], pred_sr[0]]
    title2 = ["Target", "Pred_SR"]
    for i in range(2):
        plt.subplot(1, 2, i + 1)
        plt.title(title2[i])
        plt.imshow(display_list2[i])
        plt.axis("off")
    plt.show()

# %%
from official.nlp import optimization  # to create AdamW optimizer

steps_per_epoch = tf.data.experimental.cardinality(train_dataset).numpy()
num_train_steps = steps_per_epoch * EPOCHS
num_warmup_steps = int(0.1 * num_train_steps)

init_lr = 1e-2
generator_optimizer = optimization.create_optimizer(
    init_lr=init_lr,
    num_train_steps=num_train_steps,
    num_warmup_steps=num_warmup_steps,
    optimizer_type="adamw",
)

# %%
from tqdm import tqdm


@tf.function
def train_step(model, makeup_img, non_img, hr_img):
    with tf.GradientTape() as tape:
        # output
        pred_non, pred_sr = model([makeup_img], training=True)
        loss_non = tf.reduce_mean(tf.square(pred_non - non_img)) * 100
        loss_sr = tf.reduce_mean(tf.square(pred_sr - hr_img)) * 100
        loss = 2 * loss_non + loss_sr

    generator_gradients = tape.gradient(loss, model.trainable_variables)
    generator_optimizer.apply_gradients(
        zip(generator_gradients, model.trainable_variables)
    )

    return loss


def fit(model, train_ds, epochs, val_ds):
    best_pnsr = 0.0
    step_counter = 0
    for epoch in range(epochs):
        # Train
        total_loss = 0.0
        for makeup_img, non_img, hr_img in tqdm(train_ds):
            loss = train_step(model, makeup_img, non_img, hr_img)
            total_loss = total_loss + loss
            step_counter += 1
        total_loss = total_loss / step_counter
        print("epoch: {}   loss: {}".format(epoch, total_loss))

        pnsr = tf.reduce_mean(evaluate(model, epoch, val_ds))
        if best_pnsr < pnsr:
            best_pnsr = pnsr

            for makeup_img, non_img, hr_img in val_ds.take(1):
                generate_images(model, makeup_img, non_img, hr_img)

# %%
from time import time

a = time()
fit(res34unet, train_dataset, EPOCHS, val_dataset)
print(time() - a)
